# %% [markdown]
# # Predicting Fukushima's Kex
#
# > Using ResNet18 model trained on KSSL dataset

# %%
#| hide
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| hide
from nbdev.showdoc import *
from nbdev.cli import *

# %%
from pathlib import Path
from fastai.vision.all import *
from fastai.data.all import *
from fastcore.transform import Pipeline
from tqdm import tqdm

from sklearn.metrics import r2_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import kennard_stone as ks

from sklearn.base import BaseEstimator, TransformerMixin
from scipy.signal import savgol_filter

from spanda.data.transforms import (SpectraBlock, AnalytesBlock, SpectraTfm, Analytes, Spectra,
                                    DerivTfm, AnalytesTfm, SNVTfm, RandWAvgTfm, AvgTfm, TrimTfm,
                                    NormalizeTfm, LogTfm)

import warnings
warnings.filterwarnings('ignore')

use_cuda = torch.cuda.is_available()
device = torch.device('cuda:0' if use_cuda else 'cpu')

# %%
# file getters
get_spectra = lambda o: L(f for f in o.ls() if not re.match('target', f.name))
get_target = lambda o: [f for f in o.ls() if re.match('target', f.name)][0]

# %% [markdown]
# ## EDA

# %% [markdown]
# ### PCA on KSSL

# %%
## PCA on KSSL
path = Path('../../_data/kssl-mirs-v2')
paths_kssl = path.ls(); paths_kssl

# keep only when spectra in folder
paths_kssl = [p for p in tqdm(paths_kssl) if len(p.ls()) > 1]; print(f'n samples: {len(paths_kssl)}')
# Out:
# 100%|███████████████████████████████████████████████████████| 46305/46305 [00:00<00:00, 48922.65it/s]
# n samples: 46251

# %%
tfms = Pipeline([SpectraTfm, AvgTfm, DerivTfm(window_length=3, polyorder=2), SNVTfm])
X_kssl = np.concatenate([tfms(get_spectra(p)).numpy() for p in paths_kssl])

# %%
X_kssl.shape
# Out:
# (46251, 1700)

# %%
pca_kssl = PCA(n_components=20)
X_kssl_pca = pca_kssl.fit_transform(X_kssl)
cumsum = np.cumsum(pca_kssl.explained_variance_ratio_); cumsum
# Out:
# array([0.30835888, 0.46708834, 0.56939   , 0.63544846, 0.6882231 ,
#        0.7379089 , 0.7659158 , 0.79059607, 0.8116294 , 0.8302416 ,
#        0.8466644 , 0.85818803, 0.86813354, 0.87756056, 0.8857799 ,
#        0.89345795, 0.9003919 , 0.9069469 , 0.91315925, 0.91915995],
#       dtype=float32)

# %%
plt.scatter(X_kssl_pca[:,0], X_kssl_pca[:,1], s=1, alpha=0.1);

# %% [markdown]
# ### Fuku. projection on KSSL

# %%
# EDA on Fuku.
path = Path('../../_data/seibersdorf-mirs')
paths = path.ls(); paths
# Out:
# (#176) [Path('../../_data/seibersdorf-mirs/135'),Path('../../_data/seibersdorf-mirs/95'),Path('../../_data/seibersdorf-mirs/66'),Path('../../_data/seibersdorf-mirs/104'),Path('../../_data/seibersdorf-mirs/68'),Path('../../_data/seibersdorf-mirs/103'),Path('../../_data/seibersdorf-mirs/168'),Path('../../_data/seibersdorf-mirs/157'),Path('../../_data/seibersdorf-mirs/150'),Path('../../_data/seibersdorf-mirs/159')...]

# %%
tfms = Pipeline([SpectraTfm, AvgTfm, TrimTfm, DerivTfm(window_length=3, polyorder=2), SNVTfm])

X = np.concatenate([tfms(get_spectra(p)).numpy() for p in paths])
X.shape
# Out:
# (176, 1700)

# %%
def plot_spectra(X, X_names, sample=50, alpha=0.8, color='#333', figsize=(20, 4)):
    fig, ax = plt.subplots(figsize=figsize)
    idx = np.random.randint(X.shape[0], size=sample)
    ax.set_xlim(np.max(X_names), np.min(X_names))
    plt.locator_params(axis="x", nbins=20)
    plt.xlabel('Wavenumber')
    plt.ylabel('Absorbance')
    _ = ax.plot(X_names, X[idx, :].T, lw=1, c=color, alpha=alpha)

# %%
wns = np.arange(4000, 600, -2)
plot_spectra(X, wns)

# %%
X_pca = pca_kssl.transform(X)

# %%
plt.scatter(X_kssl_pca[:,0], X_kssl_pca[:, 1], s=1, c='tab:blue', alpha=0.1)
plt.scatter(X_pca[:,0], X_pca[:,1], s=1, c='tab:red', alpha=1);

# %% [markdown]
# ## Learning

# %%
# Kennard-Stone based splitting
tfms = Pipeline([SpectraTfm, AvgTfm, TrimTfm])
X = np.concatenate([tfms(get_spectra(p)).numpy() for p in paths])

#Xs = np.concatenate([AvgTfm()(SpectraTfm()(get_spectra(p))).numpy() for p in paths])
_, _, _, val_idx = ks.train_test_split(Xs, range(len(X)), test_size=0.2)

# %%
# kd_cs133', 'ex_cs_total_cs_ratio', 'cs137', 'cs137_total', 'ex_cs137', 'ex_k2o', 'ph', 'c',
# 'n', 'c_n_ratio', 'ex_mgo', 'ex_cao', 'cec'
analyte = 'ex_k2o'

# %%
class cmolKgTfm(Transform):
    def __init__(self, 
                 atomW:float=39.098, # default is K's standard atomic weight
                ): 
        self.atomW = atomW 
        
    def encodes(self, ys:Analytes):
        return ys / self.atomW

# %%
def evaluate(model, dls):
    model.eval()
    y_hats = []
    y_trues = []
    for xb, yb in dls:
        y_hats.append(model(xb).detach().numpy())
        y_trues.append(yb.numpy())
    return (np.concatenate(y) for y in (y_hats, y_trues))

# %%
n_smp = None # None for all
dblock = DataBlock(blocks=(SpectraBlock, AnalytesBlock(analytes=[analyte])),
                   get_x=get_spectra,
                   get_y=get_target,
                   #splitter=RandomSplitter(),
                   splitter=IndexSplitter(val_idx),
                   item_tfms=[RandWAvgTfm(), TrimTfm(), SNVTfm(),
                              cmolKgTfm(), LogTfm()])

dls = dblock.dataloaders(paths[:n_smp], bs=16, drop_last=False)

# %%
dls.show_batch(max_n=3)

# %%
# Create model
model = xresnet18(ndim=1, c_in=1, ks=3, n_out=1).to(device)

# %%
# Load KSSL trained model
weights_paths = '../../_data/models/xresnet18-kex-mirs-kssl-20-epochs-lr-1e3-r2-0.813-260323.pth'
xresnet_dict = torch.load(weights_paths, map_location=torch.device('cpu')) 
model.load_state_dict(xresnet_dict['model'])
# Out:
# <All keys matched successfully>

# %%
y_hat, y_true = evaluate(model, dls.train)
print('r2: ', r2_score(y_true, y_hat))
plt.scatter(y_hat, y_true, s=10);
# Out:
# r2:  -1.821571458960654

# %% [markdown]
# ## Finetuning

# %%
# Create learner
learn = Learner(dls, model, loss_func=MSELossFlat(), metrics=R2Score()).to_fp16()

# %%
learn.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# XResNet (Input shape: 16 x 1 x 1700)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      16 x 32 x 850
# Conv1d                                    96         False
# BatchNorm1d                               64         False
# ReLU
# Conv1d                                    3072       False
# BatchNorm1d                               64         False
# ReLU
# ____________________________________________________________________________
#                      16 x 64 x 850
# Conv1d                                    6144       False
# BatchNorm1d                               128        False
# ReLU
# ____________________________________________________________________________
#                      16 x 64 x 425
# MaxPool1d
# Conv1d                                    12288      False
# BatchNorm1d                               128        False
# ReLU
# Conv1d                                    12288      False
# BatchNorm1d                               128        False
# Sequential
# ReLU
# Conv1d                                    12288      False
# BatchNorm1d                               128        False
# ReLU
# Conv1d                                    12288      False
# BatchNorm1d                               128        False
# Sequential
# ReLU
# ____________________________________________________________________________
#                      16 x 128 x 213
# Conv1d                                    24576      False
# BatchNorm1d                               256        False
# ReLU
# Conv1d                                    49152      False
# BatchNorm1d                               256        False
# ____________________________________________________________________________
#                      16 x 64 x 213
# AvgPool1d
# ____________________________________________________________________________
#                      16 x 128 x 213
# Conv1d                                    8192       False
# BatchNorm1d                               256        False
# ReLU
# Conv1d                                    49152      False
# BatchNorm1d                               256        False
# ReLU
# Conv1d                                    49152      False
# BatchNorm1d                               256        False
# Sequential
# ReLU
# ____________________________________________________________________________
#                      16 x 256 x 107
# Conv1d                                    98304      False
# BatchNorm1d                               512        False
# ReLU
# Conv1d                                    196608     False
# BatchNorm1d                               512        False
# ____________________________________________________________________________
#                      16 x 128 x 107
# AvgPool1d
# ____________________________________________________________________________
#                      16 x 256 x 107
# Conv1d                                    32768      False
# BatchNorm1d                               512        False
# ReLU
# Conv1d                                    196608     False
# BatchNorm1d                               512        False
# ReLU
# Conv1d                                    196608     False
# BatchNorm1d                               512        False
# Sequential
# ReLU
# ____________________________________________________________________________
#                      16 x 512 x 54
# Conv1d                                    393216     False
# BatchNorm1d                               1024       False
# ReLU
# Conv1d                                    786432     False
# BatchNorm1d                               1024       False
# ____________________________________________________________________________
#                      16 x 256 x 54
# AvgPool1d
# ____________________________________________________________________________
#                      16 x 512 x 54
# Conv1d                                    131072     False
# BatchNorm1d                               1024       False
# ReLU
# Conv1d                                    786432     False
# BatchNorm1d                               1024       False
# ReLU
# Conv1d                                    786432     False
# BatchNorm1d                               1024       False
# Sequential
# ReLU
# ____________________________________________________________________________
#                      16 x 512 x 1
# AdaptiveAvgPool1d
# ____________________________________________________________________________
#                      16 x 512
# Flatten
# Dropout
# ____________________________________________________________________________
#                      16 x 1
# Linear                                    513        True
# ____________________________________________________________________________
#
# Total params: 3,853,409
# Total trainable params: 513
# Total non-trainable params: 3,852,896
#
# Optimizer used: <function Adam>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - MixedPrecision
#   - Recorder
#   - ProgressCallback

# %%
#learn.freeze()

# %%
# 0, 1, 4, 5
#list(learn.model.parameters())[0].shape
# Out:
# torch.Size([32, 1, 3])

# %%
# freeze all
for m in learn.model.parameters():
    m.requires_grad = False

# %%
# Unfreeze last linear
list(learn.model.parameters())[-2].requires_grad = True

# %%
# unfreeze first and last
#for i in [0, 1, 3, 4]:
#    list(learn.model.parameters())[i].requires_grad = True

# %%
#learn.freeze_to(-1)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.009120108559727669)

# %%
learn.fit_one_cycle(20, 5e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>r2_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.020175</td>
#       <td>0.041259</td>
#       <td>0.422136</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.020038</td>
#       <td>0.042735</td>
#       <td>0.401464</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.020896</td>
#       <td>0.041389</td>
#       <td>0.420324</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021245</td>
#       <td>0.045296</td>
#       <td>0.365602</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021697</td>
#       <td>0.048171</td>
#       <td>0.325335</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.021614</td>
#       <td>0.042645</td>
#       <td>0.402731</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.020726</td>
#       <td>0.045907</td>
#       <td>0.357045</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.020691</td>
#       <td>0.041170</td>
#       <td>0.423387</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.020155</td>
#       <td>0.045485</td>
#       <td>0.362952</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.020108</td>
#       <td>0.042807</td>
#       <td>0.400465</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.020190</td>
#       <td>0.042826</td>
#       <td>0.400191</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.019548</td>
#       <td>0.039683</td>
#       <td>0.444215</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.019107</td>
#       <td>0.040609</td>
#       <td>0.431242</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.018846</td>
#       <td>0.042507</td>
#       <td>0.404669</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.018997</td>
#       <td>0.046974</td>
#       <td>0.342107</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.018452</td>
#       <td>0.042929</td>
#       <td>0.398757</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.018091</td>
#       <td>0.041424</td>
#       <td>0.419833</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.017686</td>
#       <td>0.040464</td>
#       <td>0.433280</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.017346</td>
#       <td>0.044334</td>
#       <td>0.379077</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.016865</td>
#       <td>0.040714</td>
#       <td>0.429781</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Train
y_hat, y_true = evaluate(model, dls.train)
print('r2: ', r2_score(y_true, y_hat))
plt.scatter(y_hat, y_true, s=10);
# Out:
# r2:  0.7008943254860415

# %%
# Valid
y_hat, y_true = evaluate(model, dls.valid)
print('r2: ', r2_score(y_true, y_hat))
plt.scatter(y_hat, y_true, s=10);
# Out:
# r2:  0.473220192382916

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.00013182566908653826)

# %%
#learn.fit_one_cycle(20, lr_max=slice(1e-6,1e-4))
learn.fit_one_cycle(20, lr_max=slice(1e-2,1e-5))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='13' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       65.00% [13/20 02:21&lt;01:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>r2_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.087800</td>
#       <td>0.080614</td>
#       <td>-0.129041</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.088548</td>
#       <td>0.086021</td>
#       <td>-0.204780</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087857</td>
#       <td>0.080513</td>
#       <td>-0.127639</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.088383</td>
#       <td>0.075421</td>
#       <td>-0.056322</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.087698</td>
#       <td>0.074337</td>
#       <td>-0.041133</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.085608</td>
#       <td>0.078687</td>
#       <td>-0.102064</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.084128</td>
#       <td>0.083835</td>
#       <td>-0.174159</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.083913</td>
#       <td>0.074181</td>
#       <td>-0.038944</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.082868</td>
#       <td>0.076396</td>
#       <td>-0.069967</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.081983</td>
#       <td>0.073154</td>
#       <td>-0.024564</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.080509</td>
#       <td>0.076579</td>
#       <td>-0.072541</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.079548</td>
#       <td>0.078325</td>
#       <td>-0.096983</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.078025</td>
#       <td>0.068403</td>
#       <td>0.041972</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='3' class='' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [3/9 00:03&lt;00:07 0.0769]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[234], line 2
#       1 #learn.fit_one_cycle(20, lr_max=slice(1e-6,1e-4))
# ----> 2 learn.fit_one_cycle(20, lr_max=slice(1e-2,1e-5))
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/callback/schedule.py:119, in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt, start_epoch)
#     116 lr_max = np.array([h['lr'] for h in self.opt.hypers])
#     117 scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     118           'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 119 self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:256, in Learner.fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     254 self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     255 self.n_epoch = n_epoch
# --> 256 self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:193, in Learner._with_events(self, f, event_type, ex, final)
#     192 def _with_events(self, f, event_type, ex, final=noop):
# --> 193     try: self(f'before_{event_type}');  f()
#     194     except ex: self(f'after_cancel_{event_type}')
#     195     self(f'after_{event_type}');  final()
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:245, in Learner._do_fit(self)
#     243 for epoch in range(self.n_epoch):
#     244     self.epoch=epoch
# --> 245     self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:193, in Learner._with_events(self, f, event_type, ex, final)
#     192 def _with_events(self, f, event_type, ex, final=noop):
# --> 193     try: self(f'before_{event_type}');  f()
#     194     except ex: self(f'after_cancel_{event_type}')
#     195     self(f'after_{event_type}');  final()
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:239, in Learner._do_epoch(self)
#     238 def _do_epoch(self):
# --> 239     self._do_epoch_train()
#     240     self._do_epoch_validate()
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:231, in Learner._do_epoch_train(self)
#     229 def _do_epoch_train(self):
#     230     self.dl = self.dls.train
# --> 231     self._with_events(self.all_batches, 'train', CancelTrainException)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:193, in Learner._with_events(self, f, event_type, ex, final)
#     192 def _with_events(self, f, event_type, ex, final=noop):
# --> 193     try: self(f'before_{event_type}');  f()
#     194     except ex: self(f'after_cancel_{event_type}')
#     195     self(f'after_{event_type}');  final()
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:199, in Learner.all_batches(self)
#     197 def all_batches(self):
#     198     self.n_iter = len(self.dl)
# --> 199     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:227, in Learner.one_batch(self, i, b)
#     225 b = self._set_device(b)
#     226 self._split(b)
# --> 227 self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:193, in Learner._with_events(self, f, event_type, ex, final)
#     192 def _with_events(self, f, event_type, ex, final=noop):
# --> 193     try: self(f'before_{event_type}');  f()
#     194     except ex: self(f'after_cancel_{event_type}')
#     195     self(f'after_{event_type}');  final()
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/learner.py:205, in Learner._do_one_batch(self)
#     204 def _do_one_batch(self):
# --> 205     self.pred = self.model(*self.xb)
#     206     self('after_pred')
#     207     if len(self.yb):
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/fastai/layers.py:490, in ResBlock.forward(self, x)
# --> 490 def forward(self, x): return self.act(self.convpath(x) + self.idpath(x))
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/conv.py:313, in Conv1d.forward(self, input)
#     312 def forward(self, input: Tensor) -> Tensor:
# --> 313     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/mambaforge/envs/spanda/lib/python3.9/site-packages/torch/nn/modules/conv.py:309, in Conv1d._conv_forward(self, input, weight, bias)
#     305 if self.padding_mode != 'zeros':
#     306     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     307                     weight, bias, self.stride,
#     308                     _single(0), self.dilation, self.groups)
# --> 309 return F.conv1d(input, weight, bias, self.stride,
#     310                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# Train
y_hat, y_true = evaluate(model, dls.train)
print('r2: ', r2_score(y_true, y_hat))
plt.scatter(y_hat, y_true, s=10);
# Out:
# r2:  0.9198457142465807

# %%
# Valid
y_hat, y_true = evaluate(model, dls.valid)
print('r2: ', r2_score(y_true, y_hat))
plt.scatter(y_hat, y_true, s=10);
# Out:
# r2:  0.432419245037878
